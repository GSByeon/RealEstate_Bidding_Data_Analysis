# %%
import pandas as pd
mpl.rc('font',family='malgun gothic')

# %%
df = pd.read_excel('06.dataset.xlsx')

# %% [markdown]
# # 경매 유찰에 영향을 미치는 요인 분석

# %% [markdown]
# ### 1) 유찰횟수별 전체 빈도

# %%
sns.countplot(x = 'failure_bidding', data = df)

# %% [markdown]
# ### 2) 지역별 유찰횟수 빈도

# %%
for i in df['sido_x'].unique():
    data = df[df['sido_x'] == i]
    sns.countplot(x = 'failure_bidding', data = data)
    sns.plt.title(i)
    plt.show()

# %% [markdown]
# ### 3) 권리문제 관련 유찰횟수 빈도

# %%
for i in df.ix[:, '공유자매수신고':'지분경매'].columns:
    data = df[df[i] == 1]
    sns.countplot(x = 'failure_bidding', data = data)
    sns.plt.title(i)
    plt.show()

# %% [markdown]
# ### 4) 토지 유형에 따른 유찰횟수 빈도

# %%
for i in df.ix[:, 'lndlevel_고지':'lndfrm_정방형'].columns:
    data = df[df[i] == 1]
    sns.countplot(x = 'failure_bidding', data = data)
    sns.plt.title(i)
    plt.show()

# %% [markdown]
# ### 4) 법 유무에 따른 유찰횟수 빈도

# %%
for i in df.ix[:, '가로구역별 최고높이':'현상변경허가 대상구역'].columns:
    data = df[df[i] == 1]
    sns.countplot(x = 'failure_bidding', data = data)
    sns.plt.title(i)
    plt.show()

# %% [markdown]
# ### 5) 이용지목 개수에 따른 유찰횟수 빈도

# %%
for j in df.ix[:, '도시지역_주거지역':'자연환경보전지역'].columns:
    for i in range(5):
        sns.distplot(np.log(df[df['failure_bidding'] == i][j]), hist = False, label = '유찰 {num}회'.format(num = i))
    plt.show()

# %% [markdown]
# ### 6) 면적에 따른 유찰횟수 빈도

# %%
for i in range(5):
    sns.distplot(df[df['failure_bidding'] == i]['log_area'], hist = False, label = '유찰 {num}회'.format(num = i))

# %% [markdown]
# ### 7) 감정가에 따른 유찰횟수 빈도

# %%
for i in range(5):
    sns.distplot(df[df['failure_bidding'] == i]['log_est_jiga'], hist = False, label = '유찰 {num}회'.format(num = i))

# %% [markdown]
# ### 8) 공시지가 대비 감정가에 따른 유찰횟수 빈도

# %%
for i in range(5):
    sns.distplot(df[df['failure_bidding'] == i]['est_jiga/jiga'], hist = False, label = '유찰 {num}회'.format(num = i))
    plt.axis([-1, 3, 0, 3.5])

# %% [markdown]
# # 낙찰가 분포 확인

# %%
for i in df['sido_x'].unique():
    x = df['log_bid_jiga'][df['sido_x'] == i]
    sns.distplot(x, hist = False, label = i);
